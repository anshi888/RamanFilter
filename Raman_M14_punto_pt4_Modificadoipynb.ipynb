# %%
import pandas as pd
filename = '/content/Raman M14 pt4 - Punto4 (1).csv'
data=pd.read_csv(filename,delimiter=',',decimal=",")
#pasar excel en formato numerico
data
# Out:
#              X          Y
# 0      202.499   76.47783
# 1      203.013   73.28222
# 2      203.530   48.07208
# 3      204.045  112.36495
# 4      204.561   82.66632
# ...        ...        ...
# 7886  3398.580   72.39217
# 7887  3398.900   93.70699
# 7888  3399.220  130.03181
# 7889  3399.540   81.35662
# 7890  3399.850   63.66098
#
# [7891 rows x 2 columns]

# %%
from numpy import *

x= data.X
y= data.Y
#pasar datos
x1= []
y1=[]
#print(x)
for c in range(len(x)):
    x1.append(float(x[c]))
    y1.append(float(y[c]))
#print(type(x1))
#print(x1)
#print(y1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(26,10))
plt.title('Datos con ruido',fontsize = 22)
plt.xlabel('X',fontsize = 22)
plt.ylabel('Y',fontsize = 22)
plt.ylim(0,600)
plt.xlim(200,3400)
plt.plot(x1,y1,color='gray')
plt.savefig('señalorginal.png')

# %%
from numpy import *
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter as savgol

yf1 =  savgol(data.Y,11,1)

for u in range(len(y1)):
  data.Y[u] = yf1[u]

# %%
data.to_csv('datafiltradaM14PT4.csv',sep=',')

# %%
from numpy import *
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter as savgol

# %%
plt.figure(figsize=(30,13))
plt.xlabel('X',fontsize = 22)
plt.ylabel('Y',fontsize = 22)
plt.title('Comparacion entre Señal original y Señal filtrada',fontsize = 22)
plt.plot(x1,y1, color='gray')
plt.ylim(0,600)
plt.xlim(200,3400)
plt.plot(x1 , savgol(data.Y,11,1) , label='81' , alpha=0.7,color='black' )
plt.savefig('comparacion2.png')
