# %%
import pandas as pd
filename = '/content/Punto 4_1.csv'
data=pd.read_csv(filename,delimiter=',',decimal=",")

print(data)
# Out:
#              X       Y
# 0      202.513  52.982
# 1      203.030  48.266
# 2      203.547  43.550
# 3      204.061  45.832
# 4      204.578  68.116
# ...        ...     ...
# 7884  3398.600  38.685
# 7885  3398.920  43.729
# 7886  3399.240  34.774
# 7887  3399.560  50.817
# 7888  3399.880  41.862
#
# [7889 rows x 2 columns]

# %%
from numpy import *

x= data.X
y= data.Y
#pasar datos
x1= []
y1=[]
#print(x)
for c in range(len(x)):
    x1.append(float(x[c]))
    y1.append(float(y[c]))
#print(type(x1))
#print(x1)

# %%
from numpy import *
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter as savgol

yf1 =  savgol(data.Y,71,9)

for u in range(len(y1)):
  data.Y[u] = yf1[u]

# %%
print(data.Y)

data.to_csv('raman1filtrada4.csv',sep=',')
# Out:
# 0       50.876178
# 1       48.054889
# 2       49.036714
# 3        52.24592
# 4       56.538406
#           ...
# 7884    37.430477
# 7885    38.510587
# 7886    40.056951
# 7887    42.454567
# 7888    46.299524
# Name: Y, Length: 7889, dtype: object

# %%
from numpy import *
import matplotlib.pyplot as plt
# Y los graficamos
plt.figure(figsize=(26,10))
plt.title('Datos con ruido')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,8000)
plt.xticks(range(0,8000,1000))
plt.plot(data.X.to_numpy(), data.Y)
plt.savefig('SeñalOriginal4.png')

# %% [markdown]
# Filtro Aplicada a la señal

# %%
from scipy.signal import savgol_filter as savgol
plt.figure(figsize=(32,10))
plt.title('Señal filtrada ')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,7900)
plt.xticks(range(0,8000,1000))

plt.plot(data.X.to_numpy() , savgol(data.Y,71,9) , label='71' , alpha=1 ,color='black')
plt.savefig('SeñalFiltrada4.png')

# %%
from scipy.signal import savgol_filter as savgol
plt.figure(figsize=(32,10))
plt.title('Comparacion entre la señal original y señal filtrada ')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(0,7900)
plt.xticks(range(0,8000,1000))
plt.plot(data.X.to_numpy(), data.Y,color='gray')

plt.plot(data.X.to_numpy() , savgol(data.Y,71,9) , label='71' , alpha=1 ,color='black')
plt.savefig('Comparacion4.png')
